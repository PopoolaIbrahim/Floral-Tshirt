# %% [markdown]
# <a href="https://colab.research.google.com/github/PopoolaIbrahim/Floral-Tshirt/blob/main/Floral_T_Shirt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Zazzle Design Link**

# %%
# Women's Basic T-Shirt
project_repository = "Pattern-Design"
n = 1000
while n <= 1011:
  pattern_design = f"flower_{n}.png"
  link = f"https://www.zazzle.com/api/create/at-238395068421844107?rf=238395068421844107&pd=256305536162195853&ed=true&ax=Linkover&t_image1_iid=https%3A%2F%2Fpopoolaibrahim.github.io%2F{project_repository}%2F{pattern_design}"
  print(link)
  n = n + 1
# Out:
# https://www.zazzle.com/api/create/at-238395068421844107?rf=238395068421844107&pd=256305536162195853&ed=true&ax=Linkover&t_image1_iid=https%3A%2F%2Fpopoolaibrahim.github.io%2FPattern-Design%2Fflower_1000.png
# https://www.zazzle.com/api/create/at-238395068421844107?rf=238395068421844107&pd=256305536162195853&ed=true&ax=Linkover&t_image1_iid=https%3A%2F%2Fpopoolaibrahim.github.io%2FPattern-Design%2Fflower_1001.png
# https://www.zazzle.com/api/create/at-238395068421844107?rf=238395068421844107&pd=256305536162195853&ed=true&ax=Linkover&t_image1_iid=https%3A%2F%2Fpopoolaibrahim.github.io%2FPattern-Design%2Fflower_1002.png
# https://www.zazzle.com/api/create/at-238395068421844107?rf=238395068421844107&pd=256305536162195853&ed=true&ax=Linkover&t_image1_iid=https%3A%2F%2Fpopoolaibrahim.github.io%2FPattern-Design%2Fflower_1003.png
# ...

# %% [markdown]
# **Image Generation**

# %%
# !pip install --upgrade huggingface-hub
# %pip install --quiet --upgrade diffusers transformers accelerate invisible_watermark mediapy
use_refiner = False
import mediapy as media
import random
import sys
import torch

from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    torch_dtype=torch.float16,
    use_safetensors=True,
    variant="fp16",
    )

if use_refiner:
  refiner = DiffusionPipeline.from_pretrained(
      "stabilityai/stable-diffusion-xl-refiner-1.0",
      text_encoder_2=pipe.text_encoder_2,
      vae=pipe.vae,
      torch_dtype=torch.float16,
      use_safetensors=True,
      variant="fp16",
  )

  refiner = refiner.to("cuda")

  pipe.enable_model_cpu_offload()
else:
  pipe = pipe.to("cuda")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 32.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 47.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.7 MB/s eta 0:00:00
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...

# %%
prompt = """ A beautiful lady at the center of the photograph in a colourful flower garden,4k resolution, ultrarealistic uhd faces, Kodak Ultramax 800, pexels, 85mm, casual pose, 35mm film roll photo, hard light, detailed skin texture, a masterpiece, sharp focus, pretty, perfect, super model, adorable, attractive, Hasselblad,"""
prompt = "A serene village nestled between rolling hills and lush greenery, bathed in the warm glow of sunlight"
seed = random.randint(0, sys.maxsize)
n_prompt = "easynegative, bad-hands-5, bad, ugly, bad anatomy, cropped, lowres, out of frame, blurred, disfigured, deformed"
#prompt = "A photograph of a beaming 9 year old girl, surrounded by her friends at a colorful and lively birthday party, captured during midday with natural lighting streaming in through a large window. The picture is shot with a canon EOS Rebel T7i camera, using a 35mm f/1.8 lens, highlighting the excitement and joy of the moment"
images = pipe(
    prompt = prompt,
    negative_prompt=n_prompt,
    output_type = "latent" if use_refiner else "pil",
    generator = torch.Generator("cuda").manual_seed(seed),
    ).images

if use_refiner:
  images = refiner(
      prompt = prompt,
      image = images,
      ).images

print(f"Prompt:\t{prompt}\nSeed:\t{seed}")
#media.show_images(images)
images[0].save("caption_output.png")
# Out:
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['blad,']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['blad,']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Prompt:	 A beautiful lady at the center of the photograph in a colourful flower garden,4k resolution, ultrarealistic uhd faces, Kodak Ultramax 800, pexels, 85mm, casual pose, 35mm film roll photo, hard light, detailed skin texture, a masterpiece, sharp focus, pretty, perfect, super model, adorable, attractive, Hasselblad,
# Seed:	6354540931749679298

# %% [markdown]
# **MockUp Generation**

# %%
import requests
import os
from PIL import Image
from IPython.display import display

####### Mockup 1 Generation
### Downloading Mockup 1
url = 'https://popoolaibrahim.github.io/Pattern-Design/T-shirt_mockup3.png'
r = requests.get(url)
with open('T-shirt_mockup3.png', 'wb') as f:
    f.write(r.content)
os.system("mkdir -p mockups")
n = 121
while n <= 1100:
  url = f'https://popoolaibrahim.github.io/Pattern-Design/flower_{n}.png'
  r = requests.get(url)
  with open(f'flower_{n}.png', 'wb') as f:
      f.write(r.content)
  base_img = Image.open("T-shirt_mockup3.png")
  overlay_img = Image.open(f"flower_{n}.png")
  overlay_img = overlay_img.resize((500,500),resample=Image.LANCZOS)
  base_img.paste(overlay_img, (750, 700))
  #display(base_img)
  base_img.save(f"mockups/mockup_{n}.png")
  os.remove(f'flower_{n}.png')
  n = n + 1
os.remove(f'T-shirt_mockup3.png')

#### Up to 15% OFF 🥰 CHECK MY BIO #viral #trending #floral #floraldesign #floralart #floralfoam #floralarrangements #tshirt #tshirts #tshirtbusiness #tshirtdesign

# %% [markdown]
# **Pin Generation**

# %%
from PIL import Image
import os
import io
import requests

#Remove Directory
#import shutil
#shutil.rmtree("pins")
os.system("mkdir -p pins")
# Download shop now image
url = 'https://popoolaibrahim.github.io/Pattern-Design/shop_now.png'
response = requests.get(url)
n = 121
while n <= 1100:
  ## Resizing mockup image to 1280
  image = Image.open(f"mockups/mockup_{n}.png")
  # Crop the image
  cropped_image = image.resize((1280,1280), resample=Image.LANCZOS)
  # Save the cropped image
  cropped_image.save('resized.png')
  # Replace with your input image path
  input_image_path = 'resized.png'
  output_image_path = f'pins/pin_{n}.png'
  # Define the crop coordinates (left, top, right, bottom)
  crop_coordinates = (280, 0, 1000, 1280)
  # Open the image file
  image = Image.open(input_image_path)
  # Crop the image
  cropped_image = image.crop(crop_coordinates)
  # placing the shop now image
  shop_now = Image.open(io.BytesIO(response.content))
  cropped_image.paste(shop_now,(220,1100))
  cropped_image.save(output_image_path)
  n = n + 1

# %% [markdown]
# **Pin Upload to Github**

# %%
# Uploading html files to Github
# !pip install PyGithub
from github import Github
from natsort import natsorted
import os
from google.colab import userdata

github_token = userdata.get(github_token)
github_username = "PopoolaIbrahim"
repository_name =  "PopoolaIbrahim/Floral-Tshirt"
html_list = os.listdir("pins")
sorted_html_list = natsorted(html_list) #[0:100][102:1120]
for html_file in sorted_html_list:
  file_name = html_file
  file_path = f"pins/{file_name}"
  commit_message = f'Add {html_file}'  # Commit message
  # Initialize the GitHub client
  g = Github(github_token)
  # Get the repository
  repo = g.get_repo(repository_name)
  branch_name = 'main'
  # Get the branch
  branch = repo.get_branch(branch_name)

  # Create a new file in the repository
  #contents = repo.create_file(path=file_name, message=commit_message, content=open(file_path, 'rb').read(), branch=branch_name)

  # Update existing file in the repository
  existing_file = repo.get_contents(file_name)
  contents = repo.update_file(path=file_name, message=commit_message, content=open(file_path, 'rb').read(), sha=existing_file.sha, branch=branch_name)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 12.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# ...

# %% [markdown]
# **Creating Scene 1**
# *Installing Moviepy, Imagemagick, Imageio*

# %%
# %pip install --quiet --upgrade diffusers transformers accelerate invisible_watermark mediapy
use_refiner = False
import mediapy as media
import random
import sys
import torch

from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    torch_dtype=torch.float16,
    use_safetensors=True,
    variant="fp16",
    )

if use_refiner:
  refiner = DiffusionPipeline.from_pretrained(
      "stabilityai/stable-diffusion-xl-refiner-1.0",
      text_encoder_2=pipe.text_encoder_2,
      vae=pipe.vae,
      torch_dtype=torch.float16,
      use_safetensors=True,
      variant="fp16",
  )

  refiner = refiner.to("cuda")

  pipe.enable_model_cpu_offload()
else:
  pipe = pipe.to("cuda")


# Install ImageMagick
# !pip install imageio==2.25.1
# !pip install moviepy
# !apt install imagemagick
# !apt install libmagick++-dev
# !cat /etc/ImageMagick-6/policy.xml | sed 's/none/read,write/g'> /etc/ImageMagick-6/policy.xml

### Click Restart SESSION
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 25.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.4 MB/s eta 0:00:00
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# model_index.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# text_encoder_2/config.json:   0%|          | 0.00/575 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# ...

# %% [markdown]
# **Video Generation - ZOOM In Effect**

# %% [markdown]
# os.system("mkdir -p videos")
# def zoom_in_effect(clip, zoom_ratio=0.04):
#     def effect(get_frame, t):
#         img = Image.fromarray(get_frame(t))
#         base_size = img.size
#
#         new_size = [
#             math.ceil(img.size[0] * (1 + (zoom_ratio * t))),
#             math.ceil(img.size[1] * (1 + (zoom_ratio * t)))
#         ]
#
#         # The new dimensions must be even.
#         new_size[0] = new_size[0] + (new_size[0] % 2)
#         new_size[1] = new_size[1] + (new_size[1] % 2)
#
#         img = img.resize(new_size, Image.LANCZOS)
#
#         x = math.ceil((new_size[0] - base_size[0]) / 2)
#         y = math.ceil((new_size[1] - base_size[1]) / 2)
#
#         img = img.crop([
#             x, y, new_size[0] - x, new_size[1] - y
#         ]).resize(base_size, Image.LANCZOS)
#
#         result = numpy.array(img)
#         img.close()
#         return result
#     return clip.fl(effect)
# size = (720, 1280)
# v = 1    # number of videos to produce
# p = 1    # image numbers to use p = v X 4, if v =1 then p=1
# while p <= 120 and v <= 30:
#   # Generating the scene 1
#   prompt = """ A beautiful lady at the center of the photograph in a colourful flower garden,4k resolution, ultrarealistic uhd faces, Kodak Ultramax 800, pexels, 85mm, casual pose, 35mm film roll photo, hard light, detailed skin texture, a masterpiece, sharp focus, pretty, perfect, super model, adorable, attractive, Hasselblad,"""
#   seed = random.randint(0, sys.maxsize)
#   n_prompt = "easynegative, bad-hands-5, bad, ugly, bad anatomy, cropped, lowres, out of frame, blurred, disfigured, deformed"
#   #prompt = "A photograph of a beaming 9 year old girl, surrounded by her friends at a colorful and lively birthday party, captured during midday with natural lighting streaming in through a large window. The picture is shot with a canon EOS Rebel T7i camera, using a 35mm f/1.8 lens, highlighting the excitement and joy of the moment"
#   images = pipe(
#       prompt = prompt,
#       negative_prompt=n_prompt,
#       output_type = "latent" if use_refiner else "pil",
#       generator = torch.Generator("cuda").manual_seed(seed),
#       ).images
#   if use_refiner:
#     images = refiner(prompt = prompt,image = images,).images
#   print(f"Prompt:\t{prompt}\nSeed:\t{seed}")
#   #media.show_images(images)
#   images[0].save("caption_output.png")
#
#   ### Cropping the caption output image and  creating caption background image
#   # Define the crop coordinates (left, top, right, bottom)
#   crop_coordinates = (152, 0, 872, 1024)
#   # Open the image file
#   image = Image.open("caption_output.png")
#   # Crop the image
#   cropped_image = image.crop(crop_coordinates)
#   caption_background = Image.new("RGB", (720, 1280), "black")
#   caption_background.paste(cropped_image,(0,128))
#   caption_background.save("caption_background.png")
#   caption = ["POV: \n\n You're attending a \n floral bash. \n\n Choose your design",
#             "POV: \n\n If you know your gf  \n so well ..... \n\n Which T-shirt would \n she pick?",
#             "Which T-shirt design \n will make your gf \n say yes?",
#              "Select one Floral T-Shirt",
#              "Pick one Floral T-Shirt",
#              "Choose one Floral T-Shirt",
#             "POV: \n\n Congratulations \n you just won \n a T-Shirt. \n\n Pick one\n"]
#   text_clip = TextClip(txt=random.choice(caption),fontsize=50,color="white") #size=(0, 200),font="lane",bg_color="white",
#   text_clip = text_clip.set_position('center')
#   tc_width, tc_height = text_clip.size
#   color_clip = ColorClip(size=(tc_width+100, tc_height+100), color=(100,0,0))
#   color_clip = color_clip.set_opacity(.8)
#   #color_clip.save_frame("color_clip.png")
#   #text_clip.save_frame("out.png")
#   final_clip = CompositeVideoClip([color_clip, text_clip])
#   #final_clip.save_frame("final.png")
#   im_clip = ImageClip("caption_background.png")
#   final_clip = final_clip.set_position("center")
#   final_output = CompositeVideoClip([im_clip, final_clip])
#   final_output.save_frame("scene_1.png")
#
#   # Downloading other scene
#   images = [
#       f"https://popoolaibrahim.github.io/Floral-Tshirt/pin_{p}.png",
#       f"https://popoolaibrahim.github.io/Floral-Tshirt/pin_{p + 1}.png",
#       f"https://popoolaibrahim.github.io/Floral-Tshirt/pin_{p + 2}.png",
#       f"https://popoolaibrahim.github.io/Floral-Tshirt/pin_{p + 3}.png"
#       ]
#   slides = []
#   slides.append(mp.ImageClip("scene_1.png").set_fps(25).set_duration(2).resize(size))
#   zoom_in_effect(slides[0], 0.04)
#   for n, url in enumerate(images):
#       response = requests.get(url)
#       # Check if the request was successful (status code 200)
#       #print(url)
#       if response.status_code == 200:
#           # Save the image to your computer
#           with open("img_scene.png", "wb") as f:
#               f.write(response.content)
#           print("img_scene.png downloaded successfully.")
#       else:
#           print(f"Failed to download the image. Status code: {response.status_code}")
#
#       slides.append(mp.ImageClip("img_scene.png").set_fps(25).set_duration(2).resize(size))
#       slides[n] = zoom_in_effect(slides[n], 0.04)
#   video = mp.concatenate_videoclips(slides)
#   # Add the subscribe  screen
#   response = requests.get("https://popoolaibrahim.github.io/Floral-Tshirt/subscribe.mp4")
#   with open("subscribe.mp4", "wb") as f:
#     f.write(response.content)
#   # Load the "subscribe.mp4" video clip
#   subscribe_clip = VideoFileClip("subscribe.mp4")
#   # Concatenate the existing video with the "subscribe.mp4" clip
#   final_video = concatenate_videoclips([video, subscribe_clip])
#   # Add the audio to the video
#   response = requests.get("https://popoolaibrahim.github.io/Floral-Tshirt/audio_track_1.mp3")
#   with open("audio_track_1.mp3", "wb") as f:
#     f.write(response.content)
#   # Load the audio track
#   audio_track = AudioFileClip("audio_track_1.mp3")
#   # Set the audio of the final video to the loaded audio track
#   final_video = final_video.set_audio(audio_track.subclip(2,))
#   # Save the final concatenated video with audio
#   #final_video.write_videofile(f'videos/Video_T-shirt_{v}.mp4', codec="libx264", audio_codec="aac", temp_audiofile="temp_audio.m4a", remove_temp=True)
#   final_video.write_videofile(f'videos/Video_T-shirt_{v}.mp4')
#   #print("p = ", p, "v =", v )
#   v = v + 1
#   p = p + 4

# %% [markdown]
# **Video Generation - ZOOM Out**

# %% [markdown]
# **Video Upload to Github**

# %%
# Uploading html files to Github
# !pip install PyGithub
from github import Github
from natsort import natsorted
import os

html_list = os.listdir("videos")
sorted_html_list = natsorted(html_list)
for html_file in sorted_html_list:
  github_username = "PopoolaIbrahim"
  repository_name =  "PopoolaIbrahim/Floral-Tshirt"
  github_token = "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"
  # GitHub repository information
  file_name = html_file
  file_path = f"videos/{file_name}"
  commit_message = f'Add {html_file}'  # Commit message
  # Initialize the GitHub client
  g = Github(github_token)
  # Get the repository
  repo = g.get_repo(repository_name)
  branch_name = 'main'
  # Get the branch
  branch = repo.get_branch(branch_name)

  # Create a new file in the repository
  #contents = repo.create_file(path=file_name, message=commit_message, content=open(file_path, 'rb').read(), branch=branch_name)

  # Update existing file in the repository
  existing_file = repo.get_contents(file_name)
  contents = repo.update_file(path=file_name, message=commit_message, content=open(file_path, 'rb').read(), sha=existing_file.sha, branch=branch_name)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 12.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# ...

# %%
import requests
response = requests.get("https://popoolaibrahim.github.io/Floral-Tshirt/Video_T-shirt_1.mp4")
with open("Video_T-shirt_1.mp4", "wb") as f:
  f.write(response.content)

# %%
# !pip install rembg
import requests
from rembg import remove
from PIL import Image

response = requests.get("https://popoolaibrahim.github.io/Floral-Tshirt/pin_2.png")
with open("download_pin.png", "wb") as f:
  f.write(response.content)
input_path = 'download_pin.png'
output_path = 'removed_download_pin.png'
input = Image.open(input_path)
output = remove(input)
output.save(output_path)

# %%
from PIL import Image, ImageDraw

image_width = 720
image_height = 1280
image = Image.new("RGB", (image_width, image_height), (200,0,0))
front_image = Image.open('removed_download_pin.png')
image.paste(front_image, (0,0))
image.save("output_image.png")

# %%
from PIL import Image
import math
import numpy
import numpy as np
import moviepy.editor as mp
# zoom_out_video_effect
def zoom_out_effect(clip, zoom_ratio=0.04):
    def effect(get_frame, t):
        img = Image.fromarray(get_frame(t))
        base_size = img.size

        new_size = [
            math.ceil(img.size[0] * (1 - (zoom_ratio * t))),
            math.ceil(img.size[1] * (1 - (zoom_ratio * t)))
        ]

        # The new dimensions must be even.
        new_size[0] = new_size[0] + (new_size[0] % 2)
        new_size[1] = new_size[1] + (new_size[1] % 2)

        img = img.resize(new_size, Image.LANCZOS)

        x = math.ceil((new_size[0] - base_size[0]) / 2)
        y = math.ceil((new_size[1] - base_size[1]) / 2)

        img = img.crop([
            x, y, new_size[0] - x, new_size[1] - y
        ]).resize(base_size, Image.LANCZOS)

        result = np.array(img)
        img.close()
        return result
    return clip.fl(effect)


# zoom_in_video_effect
def zoom_in_effect(clip, zoom_ratio=0.04):
    def effect(get_frame, t):
        img = Image.fromarray(get_frame(t))
        base_size = img.size

        new_size = [
            math.ceil(img.size[0] * (1 + (zoom_ratio * t))),
            math.ceil(img.size[1] * (1 + (zoom_ratio * t)))
        ]

        # The new dimensions must be even.
        new_size[0] = new_size[0] + (new_size[0] % 2)
        new_size[1] = new_size[1] + (new_size[1] % 2)

        img = img.resize(new_size, Image.LANCZOS)

        x = math.ceil((new_size[0] - base_size[0]) / 2)
        y = math.ceil((new_size[1] - base_size[1]) / 2)

        img = img.crop([
            x, y, new_size[0] - x, new_size[1] - y
        ]).resize(base_size, Image.LANCZOS)

        result = numpy.array(img)
        img.close()
        return result
    return clip.fl(effect)
duration = audio duration
video = mp.ImageClip("pu.jpg").set_fps(25).set_duration(duration)#.resize(size)
# zoom_in_effect
video_zoom_in_effect = zoom_in_effect(video, 0.04)
video_zoom_in_effect.write_videofile('Video_zoom_in_effect.mp4', codec="libx264", fps=25)
# zoom_out_effect
#video_zoom_out_effect = zoom_out_effect(video, 0.04)
#video_zoom_out_effect.write_videofile('Video_zoom_out_effect.mp4', codec="libx264", fps=25)
# Out:
# Moviepy - Building video Video_zoom_in_effect.mp4.
# Moviepy - Writing video Video_zoom_in_effect.mp4
# Moviepy - Done !
# Moviepy - video ready Video_zoom_in_effect.mp4
